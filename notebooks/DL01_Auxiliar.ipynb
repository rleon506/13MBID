# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)

# %%
df = pd.read_csv("../data/processed/datos_integrados.csv")
df.head(5)
# Out:
#    edad  antiguedad_empleado situacion_vivienda  ingresos objetivo_credito  \
# 0    22                123.0           ALQUILER     59000         PERSONAL
# 1    21                  5.0             PROPIA      9600        EDUCACIÓN
# 2    25                  1.0           HIPOTECA      9600            SALUD
# 3    23                  4.0           ALQUILER     65500            SALUD
# 4    24                  8.0           ALQUILER     54400            SALUD
#
#    pct_ingreso  tasa_interes  estado_credito falta_pago  antiguedad_cliente  \
# 0         0.59         16.02               1          Y                36.0
# 1         0.10         11.14               0          N                39.0
# 2         0.57         12.87               1          N                44.0
# 3         0.53         15.23               1          N                36.0
# 4         0.55         14.27               1          Y                54.0
#
# ...

# %%
resumen = df.info()
print(resumen)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10123 entries, 0 to 10122
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   edad                      10123 non-null  int64
#  1   antiguedad_empleado       10123 non-null  float64
#  2   situacion_vivienda        10123 non-null  object
#  3   ingresos                  10123 non-null  int64
#  4   objetivo_credito          10123 non-null  object
#  5   pct_ingreso               10123 non-null  float64
#  6   tasa_interes              10123 non-null  float64
#  7   estado_credito            10123 non-null  int64
#  8   falta_pago                10123 non-null  object
#  9   antiguedad_cliente        10123 non-null  float64
#  10  estado_civil              10123 non-null  object
#  11  estado_cliente            10123 non-null  object
#  12  gastos_ult_12m            10123 non-null  float64
# ...

# %%
df.dtypes
# Out:
# edad                          int64
# antiguedad_empleado         float64
# situacion_vivienda           object
# ingresos                      int64
# objetivo_credito             object
# pct_ingreso                 float64
# tasa_interes                float64
# estado_credito                int64
# falta_pago                   object
# antiguedad_cliente          float64
# estado_civil                 object
# estado_cliente               object
# gastos_ult_12m              float64
# genero                       object
# limite_credito_tc           float64
# nivel_educativo              object
# personas_a_cargo            float64
# capacidad_pago              float64
# operaciones_mensuales       float64
# presion_financiera          float64
# gasto_promedio_operacion    float64
# operaciones_mensuales_tc    float64
# estabilidad_laboral         float64
# dtype: object

# %%
print(df.loc[1])
# Out:
# edad                                         21
# antiguedad_empleado                         5.0
# situacion_vivienda                       PROPIA
# ingresos                                   9600
# objetivo_credito                      EDUCACIÓN
# pct_ingreso                                 0.1
# tasa_interes                              11.14
# estado_credito                                0
# falta_pago                                    N
# antiguedad_cliente                         39.0
# estado_civil                             CASADO
# estado_cliente                           ACTIVO
# gastos_ult_12m                           1144.0
# genero                                        M
# limite_credito_tc                       12691.0
# nivel_educativo             SECUNDARIO_COMPLETO
# personas_a_cargo                            3.0
# capacidad_pago                         0.104167
# operaciones_mensuales                       3.5
# presion_financiera                      0.17125
# ...

# %%
Verificamos que el modelo haya sido entrenado con las nuevas varialbles agregadas en la fase de preparación de los datos.

# %%
import joblib

model = joblib.load("C:/VIU_13MBID_AG1/13MBID/models/prod_model.pkl")

prep = model.named_steps["prep"]

for nombre, transformer, columnas in prep.transformers_:
    print(f"\nTransformador: {nombre}")
    print(columnas)
# Out:
# Transformador: num
# ['edad', 'antiguedad_empleado', 'ingresos', 'pct_ingreso', 'tasa_interes', 'estado_credito', 'antiguedad_cliente', 'gastos_ult_12m', 'limite_credito_tc', 'personas_a_cargo', 'capacidad_pago', 'operaciones_mensuales', 'presion_financiera', 'gasto_promedio_operacion', 'operaciones_mensuales_tc', 'estabilidad_laboral']
#
# Transformador: cat
# ['situacion_vivienda', 'objetivo_credito', 'estado_civil', 'estado_cliente', 'genero', 'nivel_educativo']
